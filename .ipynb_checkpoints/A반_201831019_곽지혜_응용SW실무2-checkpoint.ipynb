# %%
# 201831019_ 곽지혜

from bs4 import BeautifulSoup
from urllib.request import urlopen
from tqdm import tqdm_notebook
import pandas as pd
import urllib

# %%
import requests
from bs4 import BeautifulSoup
movie_name=[]
movie_point=[]
naverURL = "https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&date=20201201"
naverpage = urlopen(naverURL)
soup = BeautifulSoup(naverpage, "html.parser")
end = len(soup.find_all("td","point"))

# %%
print (soup.find_all(string='9.40'))
# Out:
# ['9.40']

# %%
print (soup.find_all(string='소년시절의 너'))
# Out:
# ['소년시절의 너']

# %%
# 영화제목
movie_title = soup.find_all("div","tit5")

movie_name = [movie_title[i].text.strip() for i in range(len(movie_title))]
movie_name
# Out:
# ['극장판 바이올렛 에버가든',
#  '부활: 그 증거',
#  '소년시절의 너',
#  '페이트 스테이 나이트 헤븐즈필 III.스프링 송',
#  '톰보이',
#  '사랑의 블랙홀',
#  '타오르는 여인의 초상',
#  '당신이 잠든 사이에',
#  '노트북',
#  '타샤 튜더',
#  '비긴 어게인',
#  '온워드: 단 하루의 기적',
#  '윤희에게',
#  '남매의 여름밤',
#  '담보',
#  '해리가 샐리를 만났을 때',
#  '1917',
#  '에이미',
#  '미스터트롯: 더 무비',
#  '위플래쉬',
#  '너의 이름은.',
#  '찬실이는 복도 많지',
#  '귀여운 여인',
#  '잠수종과 나비',
#  '퐁네프의 연인들',
#  '라라랜드',
#  '킹덤 오브 헤븐: 디렉터스 컷',
#  '렛 미 인',
#  '지옥의 묵시록',
#  '삼진그룹 영어토익반',
#  '레볼루셔너리 로드',
#  '셔터 아일랜드',
#  '런',
#  '테넷',
#  '내가 죽던 날',
#  '날씨의 아이',
#  '로미오와 줄리엣',
#  '레버넌트: 죽음에서 돌아온 자',
#  '펀치 드렁크 러브',
#  '아치와 씨팍',
#  '도굴',
#  '초미의 관심사',
#  '아가씨',
#  '호랑이보다 무서운 겨울손님',
#  '투 마더스',
#  '프리키 데스데이',
#  '기기괴괴 성형수',
#  '그린랜드',
#  '이웃사촌',
#  '오케이 마담']

# %%
# 평점
points = soup.find_all("td","point")
movie_point = [points[i].text for i in range(len(points))]
movie_point
# Out:
# ['9.51',
#  '9.43',
#  '9.40',
#  '9.23',
#  '9.20',
#  '9.15',
#  '9.06',
#  '9.06',
#  '9.05',
#  '9.04',
#  '9.03',
#  '9.00',
#  '8.99',
#  '8.97',
#  '8.90',
#  '8.89',
#  '8.86',
#  '8.84',
#  '8.84',
#  '8.79',
#  '8.78',
#  '8.70',
#  '8.70',
#  '8.66',
#  '8.62',
#  '8.61',
#  '8.61',
#  '8.51',
#  '8.45',
#  '8.42',
#  '8.38',
#  '8.38',
#  '8.28',
#  '8.27',
#  '8.09',
#  '7.98',
#  '7.97',
#  '7.84',
#  '7.75',
#  '7.61',
#  '7.50',
#  '7.30',
#  '7.14',
#  '7.03',
#  '7.02',
#  '6.94',
#  '6.88',
#  '6.86',
#  '6.38',
#  '6.32']

# %%
movie_name = []
movie_point = []

movie_name.extend([soup.find_all("div","tit5")[n].a.string for n in range(end)])
movie_point.extend([soup.find_all("td","point")[n].string for n in range(end)])

# %%
# 결과화면 출력
data = {"name": movie_name, "point":movie_point}
data = pd.DataFrame(data)
data
# Out:
#                           name point
# 0                극장판 바이올렛 에버가든  9.51
# 1                     부활: 그 증거  9.43
# 2                      소년시절의 너  9.40
# 3   페이트 스테이 나이트 헤븐즈필 III.스프링 송  9.23
# 4                          톰보이  9.20
# 5                      사랑의 블랙홀  9.15
# 6                  타오르는 여인의 초상  9.06
# 7                   당신이 잠든 사이에  9.06
# 8                          노트북  9.05
# 9                        타샤 튜더  9.04
# 10                      비긴 어게인  9.03
# 11               온워드: 단 하루의 기적  9.00
# 12                        윤희에게  8.99
# 13                     남매의 여름밤  8.97
# 14                          담보  8.90
# 15               해리가 샐리를 만났을 때  8.89
# 16                        1917  8.86
# 17                         에이미  8.84
# 18                 미스터트롯: 더 무비  8.84
# 19                        위플래쉬  8.79
# 20                     너의 이름은.  8.78
# 21                  찬실이는 복도 많지  8.70
# 22                      귀여운 여인  8.70
# 23                     잠수종과 나비  8.66
# 24                    퐁네프의 연인들  8.62
# 25                        라라랜드  8.61
# 26            킹덤 오브 헤븐: 디렉터스 컷  8.61
# 27                       렛 미 인  8.51
# 28                     지옥의 묵시록  8.45
# 29                  삼진그룹 영어토익반  8.42
# 30                   레볼루셔너리 로드  8.38
# 31                     셔터 아일랜드  8.38
# 32                           런  8.28
# 33                          테넷  8.27
# 34                     내가 죽던 날  8.09
# 35                      날씨의 아이  7.98
# 36                    로미오와 줄리엣  7.97
# 37            레버넌트: 죽음에서 돌아온 자  7.84
# 38                   펀치 드렁크 러브  7.75
# 39                      아치와 씨팍  7.61
# 40                          도굴  7.50
# 41                     초미의 관심사  7.30
# 42                         아가씨  7.14
# 43              호랑이보다 무서운 겨울손님  7.03
# 44                       투 마더스  7.02
# 45                    프리키 데스데이  6.94
# 46                    기기괴괴 성형수  6.88
# 47                        그린랜드  6.86
# 48                        이웃사촌  6.38
# 49                      오케이 마담  6.32
